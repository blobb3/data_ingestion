# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
from pandas import json_normalize
import requests
import json
import folium

# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)
df.head(5)
# Out:
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:organic tags.diet:seafood tags.brand:website  \
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.currency:XBT tags.payment:lightning tags.payment:lightning_contactless  \
# 0               NaN                    NaN                                NaN
# 1               NaN                    NaN                                NaN
# 2               NaN                    NaN                                NaN
# 3               NaN                    NaN                                NaN
# 4               NaN                    NaN                                NaN
#
#   tags.payment:onchain
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 266 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Coop', 'Migros'])]
print(locations.head(5))

# Subsets
locations_coop = df[["lat", "lon", "tags.brand",
                     "tags.shop"]].loc[df["tags.brand"].isin(['Coop'])]
locations_migros = df[["lat", "lon", "tags.brand",
                       "tags.shop"]].loc[df["tags.brand"].isin(['Migros'])]

# Marker symbols
url_01 = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png'
url_02 = 'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-orange.png'

# Create map
map = folium.Map(location=[locations.lat.mean(),
                           locations.lon.mean()],
                 zoom_start=8,
                 control_scale=True)

# Add lat/lon of Coop supermarkets
for i in range(0, len(locations_coop)):
    folium.Marker(location=(locations_coop.iloc[i]['lat'],
                            locations_coop.iloc[i]['lon']),
                  popup=locations_coop.iloc[i]['tags.brand'],
                  icon=folium.features.CustomIcon(url_01, icon_size=(16, 28))).add_to(map)
    
# Add lat/lon of Migros supermarkets
for i in range(0, len(locations_migros)):
    folium.Marker(location=(locations_migros.iloc[i]['lat'],
                            locations_migros.iloc[i]['lon']),
                  popup=locations_migros.iloc[i]['tags.brand'],
                  icon=folium.features.CustomIcon(url_02, icon_size=(16, 28))).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31315928445f17bcb87e6d66151fe600 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31315928445f17bcb87e6d66151fe600&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31315928445f17bcb87e6d66151fe600 = L.map(
#                 &quot;map_31315928445f17bcb87e6d66151fe600&quot;,
#                 {
#                     center: [47.00777993945111, 7.998084691938252],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_31315928445f17bcb87e6d66151fe600);
#
#
#
#
#
#             var tile_layer_360153e911e47561b75873ca170f82d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_360153e911e47561b75873ca170f82d5.addTo(map_31315928445f17bcb87e6d66151fe600);
#
#
#             var marker_4ba08ab6b6e74efecfdbf6e35a0b219b = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_31315928445f17bcb87e6d66151fe600);
#
#
#         var custom_icon_23013db1bd68f7ec014b20324b874ffd = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_4ba08ab6b6e74efecfdbf6e35a0b219b.setIcon(custom_icon_23013db1bd68f7ec014b20324b874ffd);
#
#
#         var popup_ef99a49a5e2348a0ae423ed7a99d8621 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c50d27029e7b85c1a90538af8cfb9e43 = $(`&lt;div id=&quot;html_c50d27029e7b85c1a90538af8cfb9e43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_ef99a49a5e2348a0ae423ed7a99d8621.setContent(html_c50d27029e7b85c1a90538af8cfb9e43);
#
#
#
#         marker_4ba08ab6b6e74efecfdbf6e35a0b219b.bindPopup(popup_ef99a49a5e2348a0ae423ed7a99d8621)
#         ;
#
#
#
#
#             var marker_0e4a8756b4b1c227cf8413e8b7558da2 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_31315928445f17bcb87e6d66151fe600);
#
#
#         var custom_icon_ed154d0d7dfadf526102f4da9894c402 = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_0e4a8756b4b1c227cf8413e8b7558da2.setIcon(custom_icon_ed154d0d7dfadf526102f4da9894c402);
#
#
#         var popup_fe3f89bb8ab4ddbda4201a7342698bd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a31aab7ab75507a47a7595abe79c5ac = $(`&lt;div id=&quot;html_1a31aab7ab75507a47a7595abe79c5ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_fe3f89bb8ab4ddbda4201a7342698bd9.setContent(html_1a31aab7ab75507a47a7595abe79c5ac);
#
#
#
#         marker_0e4a8756b4b1c227cf8413e8b7558da2.bindPopup(popup_fe3f89bb8ab4ddbda4201a7342698bd9)
#         ;
#
#
#
#
#             var marker_ad8964dbca0b01bbd005b982ba13d855 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}
#             ).addTo(map_31315928445f17bcb87e6d66151fe600);
#
#
#         var custom_icon_015a982ad6cccf5b9036bfb4db06f4ea = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_ad8964dbca0b01bbd005b982ba13d855.setIcon(custom_icon_015a982ad6cccf5b9036bfb4db06f4ea);
#
#
#         var popup_1d97a5b85d865484aa54fdb3f0132867 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0544ea5738d4962a371bacd56d21fc1 = $(`&lt;div id=&quot;html_d0544ea5738d4962a371bacd56d21fc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_1d97a5b85d865484aa54fdb3f0132867.setContent(html_d0544ea5738d4962a371bacd56d21fc1);
#
#
#
#         marker_ad8964dbca0b01bbd005b982ba13d855.bindPopup(popup_1d97a5b85d865484aa54fdb3f0132867)
#         ;
#
#
#
#
#             var marker_0314d87c419f478af8e583a4f5b99fbb = L.marker(
#                 [47.241531, 8.7245301],
#                 {}
#             ).addTo(map_31315928445f17bcb87e6d66151fe600);
#
#
#         var custom_icon_c9d3a2532911676b4046f5f25e39af01 = L.icon({&quot;iconSize&quot;: [16, 28], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-green.png&quot;});
#         marker_0314d87c419f478af8e583a4f5b99fbb.setIcon(custom_icon_c9d3a2532911676b4046f5f25e39af01);
#
#
#         var popup_d1de52aabb9df99f2bb0765a9b5e79e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-11-09 18:00:56
# Python Version: 3.11.10
# -----------------------------------
